# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Automobile.csv')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df = pd.read_csv('C:\\Users\mdars\Documents\Automobile.csv')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
df.tail(10)
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 191         -1                 74  volvo       gas        std            four
# 192         -2                103  volvo       gas        std            four
# 193         -1                 74  volvo       gas        std            four
# 194         -2                103  volvo       gas      turbo            four
# 195         -1                 74  volvo       gas      turbo            four
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# ...

# %%
df.shape
# Out:
# (201, 26)

# %%
df.dtypes
# Out:
# symboling                int64
# normalized_losses        int64
# make                    object
# fuel_type               object
# aspiration              object
# number_of_doors         object
# body_style              object
# drive_wheels            object
# engine_location         object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# number_of_cylinders     object
# engine_size              int64
# fuel_system             object
# bore                   float64
# stroke                 float64
# compression_ratio      float64
# horsepower               int64
# peak_rpm                 int64
# city_mpg                 int64
# highway_mpg              int64
# price                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
df.iloc[21]
# Out:
# symboling                      1
# normalized_losses            118
# make                       dodge
# fuel_type                    gas
# aspiration                   std
# number_of_doors              two
# body_style             hatchback
# drive_wheels                 fwd
# engine_location            front
# wheel_base                  93.7
# length                     157.3
# width                       63.8
# height                      50.8
# curb_weight                 1876
# engine_type                  ohc
# number_of_cylinders         four
# engine_size                   90
# fuel_system                 2bbl
# bore                        2.97
# stroke                      3.23
# compression_ratio            9.4
# horsepower                    68
# peak_rpm                    5500
# city_mpg                      31
# highway_mpg                   38
# price                       6377
# Name: 21, dtype: object

# %%
df.loc[21]
# Out:
# symboling                      1
# normalized_losses            118
# make                       dodge
# fuel_type                    gas
# aspiration                   std
# number_of_doors              two
# body_style             hatchback
# drive_wheels                 fwd
# engine_location            front
# wheel_base                  93.7
# length                     157.3
# width                       63.8
# height                      50.8
# curb_weight                 1876
# engine_type                  ohc
# number_of_cylinders         four
# engine_size                   90
# fuel_system                 2bbl
# bore                        2.97
# stroke                      3.23
# compression_ratio            9.4
# horsepower                    68
# peak_rpm                    5500
# city_mpg                      31
# highway_mpg                   38
# price                       6377
# Name: 21, dtype: object

# %%
df.iloc[21]['fuel_type']
# Out:
# 'gas'

# %%
df.iloc[3:5]['fuel_type']
# Out:
# 3    gas
# 4    gas
# Name: fuel_type, dtype: object

# %%
df.iloc[:,:2]
# Out:
#      symboling  normalized_losses
# 0            3                168
# 1            3                168
# 2            1                168
# 3            2                164
# 4            2                164
# ..         ...                ...
# 196         -1                 95
# 197         -1                 95
# 198         -1                 95
# 199         -1                 95
# 200         -1                 95
#
# [201 rows x 2 columns]

# %%
df[df.length>170]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# 6            1                158         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# ...

# %%
df[df.fuel_type=='gas']
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1                 74        volvo       gas      turbo
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df[(df.fuel_type=='gas')&(df.fuel_system=='2bbl')]
# Out:
#      symboling  normalized_losses       make fuel_type aspiration  \
# 17           2                121  chevrolet       gas        std
# 18           1                 98  chevrolet       gas        std
# 19           0                 81  chevrolet       gas        std
# 20           1                118      dodge       gas        std
# 21           1                118      dodge       gas        std
# ..         ...                ...        ...       ...        ...
# 156          0                 91     toyota       gas        std
# 157          0                 91     toyota       gas        std
# 158          0                 91     toyota       gas        std
# 159          1                168     toyota       gas        std
# 160          1                168     toyota       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 17              two  hatchback          fwd           front        88.4  ...
# ...

# %%
df[(df.fuel_type=='gas')|(df.fuel_type=='diesel')]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.sort_values('length')
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 17          2                121      chevrolet       gas        std
# 29          2                137          honda       gas        std
# 30          2                137          honda       gas        std
# 33          1                101          honda       gas        std
# 32          1                101          honda       gas        std
# ..        ...                ...            ...       ...        ...
# 44          0                145         jaguar       gas        std
# 45          0                115         jaguar       gas        std
# 67         -1                 93  mercedes-benz    diesel      turbo
# 68         -1                122  mercedes-benz       gas        std
# 70          0                140  mercedes-benz       gas        std
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# ...

# %%
df['length']=df.length.rank(method='min')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df['length']=df.length.rank(method='max')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
list_automobile = [['volvo',30000],['oppo',40000],['samsung',50000],['apple',60000]]
df_mob1=pd.DataFrame(list_automobile,columns=["vname","price"])
df_mob1
# Out:
#      vname  price
# 0    volvo  30000
# 1     oppo  40000
# 2  samsung  50000
# 3    apple  60000

# %%
list_automobile = [[1,'volvo',30],[2,'oppo',40],[3,'samsung',50],[4,'apple',60]]
df_mob3=pd.DataFrame(list_automobile,columns=["index","vname","size"])
df_mob3
# Out:
#    index    vname  size
# 0      1    volvo    30
# 1      2     oppo    40
# 2      3  samsung    50
# 3      4    apple    60

# %%
list_automobile = [[1,'vivo',35000],[2,'oneplus',45000],[3,'realme',57000],[4,'apple',60000]]
df_mob2=pd.DataFrame(list_automobile,columns=["index","vnames","price"])
df_mob2
# Out:
#    index   vnames  price
# 0      1     vivo  35000
# 1      2  oneplus  45000
# 2      3   realme  57000
# 3      4    apple  60000

# %% [markdown]
# # joins

# %%
df_mob2.set_index("index").join(df_mob3.set_index("index"),on='index',how='inner')
# Out:
#         vnames  price    vname  size
# index
# 1         vivo  35000    volvo    30
# 2      oneplus  45000     oppo    40
# 3       realme  57000  samsung    50
# 4        apple  60000    apple    60

# %% [markdown]
# # Merge

# %%
pd.merge(df_mob2,df_mob3, on = 'index')
# Out:
#    index   vnames  price    vname  size
# 0      1     vivo  35000    volvo    30
# 1      2  oneplus  45000     oppo    40
# 2      3   realme  57000  samsung    50
# 3      4    apple  60000    apple    60

# %%
pd.merge(df_mob2,df_mob3, on = 'index',how = 'outer')
# Out:
#    index   vnames  price    vname  size
# 0      1     vivo  35000    volvo    30
# 1      2  oneplus  45000     oppo    40
# 2      3   realme  57000  samsung    50
# 3      4    apple  60000    apple    60

# %%
pd.merge(df_mob2,df_mob3, on = 'index',how = 'right')
# Out:
#    index   vnames  price    vname  size
# 0      1     vivo  35000    volvo    30
# 1      2  oneplus  45000     oppo    40
# 2      3   realme  57000  samsung    50
# 3      4    apple  60000    apple    60

# %%
pd.merge(df_mob2,df_mob3, on = 'index',how = 'left')
# Out:
#    index   vnames  price    vname  size
# 0      1     vivo  35000    volvo    30
# 1      2  oneplus  45000     oppo    40
# 2      3   realme  57000  samsung    50
# 3      4    apple  60000    apple    60

# %%
pd.merge(df_mob2,df_mob3,left_index = True, right_index = True)
# Out:
#    index_x   vnames  price  index_y    vname  size
# 0        1     vivo  35000        1    volvo    30
# 1        2  oneplus  45000        2     oppo    40
# 2        3   realme  57000        3  samsung    50
# 3        4    apple  60000        4    apple    60

# %%
df_melt = df_mob2.melt(id_vars=['index'])
df_melt
# Out:
#    index variable    value
# 0      1   vnames     vivo
# 1      2   vnames  oneplus
# 2      3   vnames   realme
# 3      4   vnames    apple
# 4      1    price    35000
# 5      2    price    45000
# 6      3    price    57000
# 7      4    price    60000

# %%
df_melt = df_mob2.melt(id_vars=['index'] , value_vars='vname')
df_melt
# Out:
#    index variable  value
# 0      1    price  35000
# 1      2    price  45000
# 2      3    price  57000
# 3      4    price  60000

# %% [markdown]
# # pivot

# %%
pd.pivot_table(df_mob2,index=['vnames'], values=['price'])
# Out:
#          price
# vnames
# apple    60000
# oneplus  45000
# realme   57000
# vivo     35000

# %% [markdown]
# # cross tables

# %%
pd.crosstab(df_mob2.vnames,df_mob3.size,rownames=['mobile'],colnames=['size'])
# Out:
# size     12
# mobile
# apple     1
# oneplus   1
# realme    1
# vivo      1
